# %%
from models.readout_head import Readout
from models.rvm_torch import RVM

# %%
model = RVM()
# Out:
# ...
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]

# %%
import os

path = "/home/mahesh/rvm/frozen_dino_ckpts/exp_1786079519.802173/model_epoch1_step2000.pth"

print(os.path.exists(path))
print(os.path.getsize(path))
# Out:
# True
# 0

# %%
import torch
checkpoint = torch.load("/home/mahesh/rvm/frozen_dino_ckpts/exp_1786079519.802173/model_epoch0_step1000.pth", map_location="cpu")
checkpoint.keys()
# Out:
# dict_keys(['model', 'optimizer', 'scheduler', 'epoch', 'global_step', 'config', 'local_step'])

# %%
model.load_state_dict(checkpoint['model'])
# Out:
# <All keys matched successfully>

# %%
ls[:, total-retain:]
