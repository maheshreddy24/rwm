# %%
import torch
ckpt_path = '/home/rvm/evals/intphy2/IntPhys2/checkpoint/videomaev2/vit_g_hybrid_pt_1200e.pth'
checkpoint = torch.load(ckpt_path)
checkpoint.keys()

# %%
checkpoint

# %%
import torch

losses = torch.load("/home/rvm/evals/intphy2/IntPhys2/checkpoint/videomaev2/intphys_v2/intphys2-main-default/losses_10fs_4_6_8_10_12_14ctxt_rank0.pth", weights_only = False)

# %%
losses['losses'].shape, losses['names'].shape
# Out:
# (torch.Size([60, 6, 31]), (60,))

# %%
losses.keys()
# Out:
# dict_keys(['frame_step', 'num_frames_to_pred', 'context_lengths', 'losses', 'names'])
