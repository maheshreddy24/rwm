# %%
import torch
ckpt_path = '/home/rvm/evals/intphy2/IntPhys2/checkpoint/videomaev2/vit_g_hybrid_pt_1200e.pth'
checkpoint = torch.load(ckpt_path)
checkpoint.keys()

# %%
checkpoint

# %%
import torch

losses = torch.load("/home/rvm/evals/intphy2/IntPhys2/checkpoint/videomaev2/intphys_v2/intphys2-debug-default/losses_10fs_4_6_8_10_12_14ctxt.pth", weights_only = False)

# %%
losses['losses'].shape, losses['names'].shape
# Out:
# (torch.Size([60, 6, 31]), (60,))

# %%
losses
# Out:
# {'frame_step': 10,
#  'num_frames_to_pred': -1,
#  'context_lengths': [4, 6, 8, 10, 12, 14],
#  'losses': tensor([[[0.7659, 0.7305, 0.7334,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7659, 0.7308, 0.7092,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7659, 0.7308, 0.7092,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7659, 0.7308, 0.7092,  ..., 0.7619, 0.0000, 0.0000],
#           [0.7659, 0.7308, 0.7092,  ..., 0.7746, 0.7786, 0.0000],
#           [0.7659, 0.7308, 0.7092,  ..., 0.7233, 0.7240, 0.7317]],
#
#          [[0.6754, 0.6511, 0.6483,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6754, 0.6526, 0.6375,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6754, 0.6526, 0.6379,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6754, 0.6526, 0.6379,  ..., 0.6658, 0.0000, 0.0000],
#           [0.6754, 0.6526, 0.6379,  ..., 0.6419, 0.6461, 0.0000],
#           [0.6754, 0.6526, 0.6379,  ..., 0.6247, 0.6363, 0.6280]],
#
#          [[0.7696, 0.7340, 0.7294,  ..., 0.0000, 0.0000, 0.0000],
# ...
