# %%
import numpy as np


rng = np.random.default_rng()
rng.integers()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 import numpy as np
#       2
#       3
#       4 rng = np.random.default_rng()
# ----> 5 rng.integers()
#
# File numpy/random/_generator.pyx:576, in numpy.random._generator.Generator.integers()
# --> 576 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: integers() takes at least 1 positional argument (0 given)

# %%
from
