# %%
from transformers import VideoMAEImageProcessor, AutoModel, AutoConfig
import numpy as np
import torch


config = AutoConfig.from_pretrained("OpenGVLab/VideoMAEv2-Base", trust_remote_code=True)
processor = VideoMAEImageProcessor.from_pretrained("OpenGVLab/VideoMAEv2-Base")
model = AutoModel.from_pretrained('OpenGVLab/VideoMAEv2-Base', config=config, trust_remote_code=True)


# video = list(np.random.rand(16, 3, 224, 224))




# # B, T, C, H, W -> B, C, T, H, W
# inputs = processor(video, return_tensors="pt")
# inputs['pixel_values'] = inputs['pixel_values'].permute(0, 2, 1, 3, 4)

# with torch.no_grad():
#   outputs = model(**inputs)
# Out:
# Loading weights: 100%|██████████| 160/160 [00:00<00:00, 6021.32it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 8
#       6 config = AutoConfig.from_pretrained("OpenGVLab/VideoMAEv2-Base", trust_remote_code=True)
#       7 processor = VideoMAEImageProcessor.from_pretrained("OpenGVLab/VideoMAEv2-Base")
# ----> 8 model = AutoModel.from_pretrained('OpenGVLab/VideoMAEv2-Base', config=config, trust_remote_code=True)
#      11 # video = list(np.random.rand(16, 3, 224, 224))
#      12
#      13
#    (...)
#      20 # with torch.no_grad():
#      21 #   outputs = model(**inputs)
#
# File /root/miniconda3/envs/gssl/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:385, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     383     model_class.register_for_auto_class(auto_class=cls)
#     384     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 385     return model_class.from_pretrained(
#     386         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     387     )
#     388 elif has_local_code:
#     389     model_class = _get_model_class(config, cls._model_mapping)
#
# File /root/miniconda3/envs/gssl/lib/python3.10/site-packages/transformers/modeling_utils.py:4349, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4331 load_config = LoadStateDictConfig(
#    4332     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4333     ignore_mismatched_sizes=ignore_mismatched_sizes,
#    (...)
#    4346     disable_mmap=disable_mmap,
#    4347 )
#    4348 loading_info, disk_offload_index = cls._load_pretrained_model(model, state_dict, checkpoint_files, load_config)
# -> 4349 loading_info = cls._finalize_model_loading(model, load_config, loading_info)
#    4350 model.eval()  # Set model in evaluation mode to deactivate Dropout modules by default
#    4351 model.set_use_kernels(use_kernels, kernel_config)
#
# File /root/miniconda3/envs/gssl/lib/python3.10/site-packages/transformers/modeling_utils.py:4509, in PreTrainedModel._finalize_model_loading(model, load_config, loading_info)
#    4505 model.mark_tied_weights_as_initialized(loading_info)
#    4507 # Move missing (and potentially mismatched) keys and non-persistent buffers back to their expected device from
#    4508 # meta device (because they were not moved when loading the weights as they were not in the loaded state dict)
# -> 4509 model._move_missing_keys_from_meta_to_device(
#    4510     loading_info.missing_and_mismatched(),
#    4511     load_config.device_map,
#    4512     load_config.device_mesh,
#    4513     load_config.hf_quantizer,
#    4514 )
#    4516 # Correctly initialize the missing (and potentially mismatched) keys (all parameters without the `_is_hf_initialized` flag)
#    4517 model._initialize_missing_keys(load_config.is_quantized)
#
# File /root/miniconda3/envs/gssl/lib/python3.10/site-packages/transformers/modeling_utils.py:4756, in PreTrainedModel._move_missing_keys_from_meta_to_device(self, missing_keys, device_map, device_mesh, hf_quantizer)
#    4751     return
#    4753 # The tied weight keys are in the "missing" usually, but they should not be moved (they will be tied anyway)
#    4754 # This is especially important because if they are moved, they will lose the `_is_hf_initialized` flag, and they
#    4755 # will be re-initialized for nothing (which can be quite long)
# -> 4756 for key in missing_keys - self.all_tied_weights_keys.keys():
#    4757     param = self.get_parameter_or_buffer(key)
#    4758     param_device = get_device(device_map, key, valid_torch_device=True)
#
# File /root/miniconda3/envs/gssl/lib/python3.10/site-packages/torch/nn/modules/module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'VideoMAEv2' object has no attribute 'all_tied_weights_keys'
